# %%
student_info = (("Muskan", 221015),("Sagor", 221260),("Anik", 
221210),("Shishir", 211016),("Kainat", 221215),("Fairuz", 201262),("Sabuj", 
213014), ("Samanta", 203016), ("Nabila", 213261),("Tanvir", 213264), 
("Moinul", 202016), ("Sabbir", 212215),("Kabbya", 212017), ("Hasnat", 
212216))

x={'Spring':
     {
     'CSE_UB8': [],
     'MNS_UB2': [],
     'EEE_UB5': []
     },
'Summer':
   {
     'CSE_UB8': [],
     'MNS_UB2': [],
     'EEE_UB5': []   },
'Fall':
     {
     'CSE_UB8': [],
     'EEE_UB5': [],
     'MNS_UB2': []     }
}
for i in student_info:
    if str(i[1])[2]=='1':
        if str(i[1])[3:5]== '01' :
            x['Spring']['CSE_UB8'].append(i[0])
        elif str(i[1])[3:5]== '21' :
            x['Spring']['EEE_UB5'].append(i[0])
        else:
            x['Spring']['MNS_UB2'].append(i[0])
    elif str(i[1])[2]=='3':
        if str(i[1])[3:5]== '01' :
            x['Summer']['CSE_UB8'].append(i[0])
        elif str(i[1])[3:5]== '21' :
            x['Summer']['EEE_UB5'].append(i[0])
        else:
            x['Summer']['MNS_UB2'].append(i[0])
    else:
        if str(i[1])[3:5]== '01' :
            x['Fall']['CSE_UB8'].append(i[0])
        elif str(i[1])[3:5]== '21' :
            x['Fall']['EEE_UB5'].append(i[0])
        else:
            x['Fall']['MNS_UB2'].append(i[0])

y={'Spring':
     {},
    'Summer':
    {},
    'Fall':
     {}}
for i in x.keys():
    for j in x[i].keys():
        if x[i][j]==[] or x[i][j]==[] or x[i][j]==[]:
            continue
        else:
            y[i][j]=x[i][j]
print(y)
# Out:
# {'Spring': {'CSE_UB8': ['Muskan', 'Shishir'], 'MNS_UB2': ['Sagor', 'Fairuz'], 'EEE_UB5': ['Anik', 'Kainat']}, 'Summer': {'CSE_UB8': ['Sabuj', 'Samanta'], 'MNS_UB2': ['Nabila', 'Tanvir']}, 'Fall': {'CSE_UB8': ['Moinul', 'Kabbya'], 'EEE_UB5': ['Sabbir', 'Hasnat']}}

# %%
y=input('Enter the month :')
z=int(input('Enter the days :'))
count=0
a={'Poush':15,'Magh':30,'Falgun':30,'Chaitra':30}
if x%4==0 or x%100==0 or x%400==0:
    days=366
    bangla={'Baishakh':31,'Jaishtha':31,'Ashar':31,'Srabon':31,'Bhadro':31,'Ashwin':31,'Kartik':30,'Ogrohayon':30,'Poush':30,'Magh':30,'Falgun':30,'Chaitra':30}
    english={'January':31,'February':29,'March':31,'April':30,'May':31,'June':30,'July':31,'August':31,'September':30,'October':31,'November':30,'December':31}
else:
    days=365
    bangla={'Baishakh':31,'Jaishtha':31,'Ashar':31,'Srabon':31,'Bhadro':31,'Ashwin':31,'Kartik':30,'Ogrohayon':30,'Poush':30,'Magh':30,'Falgun':29,'Chaitra':30}
    english={'January':31,'February':28,'March':31,'April':30,'May':31,'June':30,'July':31,'August':31,'September':30,'October':31,'November':30,'December':31}
for i in english.keys():
    if i==y:
        break
    else:
        count+=english[i]
count+=z
if days-count<=261:
    year=x-593
    if days==366:
        count-=104
    else:
        count-=103
    for i in bangla.keys():
        if count-bangla[i]<0:
            day=count
            break
        elif count-bangla[i]==0:
            count=bangla[i]
        else:
            count-=bangla[i]
        month=i
else:
    year=x-594
    if days==366:
        count-=104
    else:
        count-=103
    for i in a.keys():
        if count-a[i]<0:
            day=count
            break
        elif count-a[i]==0:
            count=a[i]
        else:
            count-=a[i]
        month=i
print(year)
print(month)
print(day)
